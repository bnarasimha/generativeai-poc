# %%
# !pip install langchain
# !pip install unstructured
# !pip install pypdf
# !pip install tiktoken
# !pip install chromadb
# !pip install openai
# Out:
# Requirement already satisfied: langchain in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (0.0.194)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.23)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.5.9)
# Requirement already satisfied: pydantic<2,>=1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.10.10)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: requests<3,>=2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: langchainplus-sdk>=0.0.6 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.0.20)
# Requirement already satisfied: numpy<2,>=1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.24.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pydantic<2,>=1->langchain) (4.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: packaging>=17.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (0.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (3.0.9)
# Requirement already satisfied: unstructured in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (0.8.7)
# Requirement already satisfied: filetype in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: msg-parser in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: pdfminer.six in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (20221105)
# Requirement already satisfied: markdown in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (3.3.4)
# Requirement already satisfied: xlrd in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (2.0.1)
# Requirement already satisfied: python-docx in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (0.8.11)
# Requirement already satisfied: python-magic in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: openpyxl in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (3.0.10)
# Requirement already satisfied: pillow in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (9.2.0)
# Requirement already satisfied: tabulate in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (0.8.10)
# Requirement already satisfied: pandas in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (2.0.3)
# Requirement already satisfied: pypandoc in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (1.11)
# Requirement already satisfied: nltk in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (3.7)
# Requirement already satisfied: requests in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: lxml in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (4.9.1)
# Requirement already satisfied: python-pptx in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (0.6.21)
# Requirement already satisfied: chardet in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (4.0.0)
# Requirement already satisfied: pdf2image in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from unstructured) (1.16.3)
# Requirement already satisfied: olefile>=0.46 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from msg-parser->unstructured) (0.46)
# Requirement already satisfied: tqdm in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from nltk->unstructured) (4.65.0)
# Requirement already satisfied: joblib in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from nltk->unstructured) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from nltk->unstructured) (2023.6.3)
# Requirement already satisfied: click in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from nltk->unstructured) (8.0.4)
# Requirement already satisfied: et_xmlfile in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from openpyxl->unstructured) (1.1.0)
# Requirement already satisfied: numpy>=1.20.3 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas->unstructured) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas->unstructured) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas->unstructured) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas->unstructured) (2023.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six->unstructured) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pdfminer.six->unstructured) (37.0.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from python-pptx->unstructured) (3.0.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests->unstructured) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests->unstructured) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests->unstructured) (2022.9.24)
# Requirement already satisfied: cffi>=1.12 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured) (1.15.1)
# Requirement already satisfied: six>=1.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->unstructured) (1.16.0)
# Requirement already satisfied: pycparser in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured) (2.21)
# Requirement already satisfied: pypdf in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pypdf) (4.7.1)
# Requirement already satisfied: tiktoken in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2022.9.24)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.10)
# Requirement already satisfied: chromadb in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (0.4.2)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.10.10)
# Requirement already satisfied: posthog>=2.4.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (3.0.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (7.3.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: importlib-resources in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (6.0.0)
# Requirement already satisfied: pandas>=1.3 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (2.0.3)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (3.2.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.23.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.15.1)
# Requirement already satisfied: chroma-hnswlib==0.7.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.7.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.7.1)
# Requirement already satisfied: numpy>=1.21.6 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.99.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.13.3)
# Requirement already satisfied: requests>=2.28 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: coloredlogs in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: packaging in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (21.3)
# Requirement already satisfied: protobuf in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (4.23.3)
# Requirement already satisfied: flatbuffers in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: sympy in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3->chromadb) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3->chromadb) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: certifi in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from pulsar-client>=3.1.0->chromadb) (2022.9.24)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.28->chromadb) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: click>=7.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.0.4)
# Requirement already satisfied: h11>=0.8 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.0)
# Requirement already satisfied: websockets>=10.4 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.8.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from packaging->onnxruntime>=1.14.1->chromadb) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: openai in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (0.27.2)
# Requirement already satisfied: tqdm in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from openai) (3.8.4)
# Requirement already satisfied: requests>=2.20 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from openai) (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/narasimhabadrinath/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)

# %%
import os
import tiktoken
import chromadb
from genai.credentials import Credentials
from genai.schemas import GenerateParams
from genai.model import Model

from langchain.document_loaders import OnlinePDFLoader, UnstructuredPDFLoader, PyPDFLoader
from langchain.text_splitter import TokenTextSplitter
from langchain.memory import ConversationBufferMemory
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.llms import OpenAI
from langchain.chains import ConversationalRetrievalChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/2h/kpk__fn95bx0s106p86ms03h0000gn/T/ipykernel_18561/830117238.py in <module>
#       6 from genai.model import Model
#       7
# ----> 8 from langchain.document_loaders import OnlinePDFLoader, UnstructuredPDFLoader, PyPDFLoader
#       9 from langchain.text_splitter import TokenTextSplitter
#      10 from langchain.memory import ConversationBufferMemory
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/iCloud/GitHub/generativeai-poc/ibm-generative-ai/langchain.py in <module>
# ----> 1 from langchain.document_loaders import PyPDFDirectoryLoader
#       2 from langchain.chains.question_answering import load_qa_chain
#       3 from genai.model import Credentials
#       4 from genai.schemas import GenerateParams
#       5 from genai.extensions.langchain.llm import LangChainInterface
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'; 'langchain' is not a package

# %%
loader = PyPDFLoader("../assets/gartner_vendor_rating_ibm.pdf")
pdfData = loader.load()

text_splitter = TokenTextSplitter(chunk_size=1000, chunk_overlap=0)
splitData = text_splitter.split_documents(pdfData)

# %%
collection_name = "gartner_collection"
local_directory = "gertner_vect_embedding"
persist_directory = os.path.join(os.getcwd(), local_directory)

openai_key=os.environ.get('OPENAI_API_KEY')
embeddings = OpenAIEmbeddings(openai_api_key=openai_key)
vectDB = Chroma.from_documents(splitData,
                      embeddings,
                      collection_name=collection_name,
                      persist_directory=persist_directory
                      )
vectDB.persist()

# %%
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
chatQA = ConversationalRetrievalChain.from_llm(
            OpenAI(openai_api_key=openai_key,
               temperature=0, model_name="gpt-3.5-turbo"), 
            vectDB.as_retriever(), 
            memory=memory)

# %%
chat_history = []
qry = ""
while qry != 'done':
    qry = input('Question: ')
    if qry != exit:
        response = chatQA({"question": qry, "chat_history": chat_history})
        print(response["answer"])
